# %%
import numpy as np  
import matplotlib.pyplot as plt
import gendata
import torch
from models.wdgrl_model import *
from tqdm.auto import trange

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
def clustering(
        X, 
        n_cluster: int = 2):
    kmeans = KMeans(n_clusters=n_cluster, random_state=42)
    labels = kmeans.fit_predict(X)
    return labels, kmeans

# %% [markdown]
# ## Gen data

# %%
ns, nt, d = 2000, 100, 16

# %%
Xs, Ys, Xt, Yt, info = gendata.gen_domain_adaptation_data(
    n_source=ns,
    n_target=nt,
    n_features=d,
    n_clusters=2,
    domain_shift_type="covariate",
    shift_magnitude=2.0,  # Moderate shift
    noise_ratio=0.00,
    random_state=1812140441,
    base_center = (-2,2),
    cluster_std_source = 1,
    cluster_std_target = 2,
)
# Out:
# Fixed andom seed = 1812140441

# %% [markdown]
# ## TSNE 2d plot

# %%
gendata.visualby_tsne(Xs,Xt,Ys,Yt)
# Out:
# Running t-SNE dimensionality reduction...

# %% [markdown]
# ## Original clustering

# %%
cluster_labels, model1 = clustering(Xt)

ari = adjusted_rand_score(Yt, cluster_labels)
print(f'Adjusted Rand Index (ARI) only on target domain: {ari:.4f}')
# Out:
# Adjusted Rand Index (ARI) only on target domain: 0.6363

# %% [markdown]
# ___

# %%
xs = torch.from_numpy(Xs).float()
ys = torch.from_numpy(Ys).long()
xt = torch.from_numpy(Xt).float()
yt = torch.from_numpy(Yt).long()

# %%
from torch.utils.data import DataLoader, TensorDataset

source_dataset = TensorDataset(xs)
target_dataset = TensorDataset(xt)

# %% [markdown]
# ## WDGRL

# %%
encoder_hidden_dims = [10]
critic_hidden_dims = [10,10]
model = WDGRL(
    input_dim=d, 
    encoder_hidden_dims=encoder_hidden_dims,
    critic_hidden_dims=critic_hidden_dims,
    _lr_encoder = 1e-3,
    _lr_critic = 1e-3,
    seed=42)
model.encoder = model.encoder.float()
model.critic = model.critic.float()

losses, source_critic_scores, target_critic_scores = model.train(
    source_dataset, 
    target_dataset,
    num_epochs=200,
    gamma=1,
    dc_iter= 10,
    batch_size=32)
# Out:
# Epoch: 100%|██████████| 200/200 [00:06<00:00, 31.31it/s]

# %%
xs_hat = model.extract_feature(xs.cuda())
xt_hat = model.extract_feature(xt.cuda())
xs_hat = xs_hat.cpu().numpy()
xt_hat = xt_hat.cpu().numpy()
print(xs_hat.shape)
print(xt_hat.shape)
# Out:
# (2000, 10)
# (100, 10)

# %%
x_comb = np.vstack((xs_hat, xt_hat))
comb_cluster_labels, model2 = clustering(x_comb)
ari = adjusted_rand_score(Yt, comb_cluster_labels[ns:])
print(f'Adjusted Rand Index (ARI) of target on transported domain: {ari:.4f}')
# Out:
# Adjusted Rand Index (ARI) of target on transported domain: 0.0480

# %%
gendata.visualby_tsne(xs_hat, xt_hat, Ys, Yt)
# Out:
# Running t-SNE dimensionality reduction...

# %% [markdown]
# ## Fine-tune hyperparams

# %%
n_source_small = 800
n_target_small = 80

# Randomly pick indices without replacement
src_indices = torch.randperm(len(xs))[:n_source_small]
tgt_indices = torch.randperm(len(xt))[:n_target_small]

# Create smaller tensors
xs_small = xs[src_indices]
xt_small = xt[tgt_indices]

# Subset labels (Ys, Yt are numpy arrays)
Ys_small = Ys[src_indices.cpu().numpy()]
Yt_small = Yt[tgt_indices.cpu().numpy()]

# Create smaller datasets
source_dataset_small = TensorDataset(xs_small)
target_dataset_small = TensorDataset(xt_small)

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
import numpy as np
from sklearn.metrics import adjusted_rand_score

def objective(trial):
    # Hyperparameter search space
    # encoder_hidden_dims = trial.suggest_categorical("encoder_hidden_dims", [[32], [10,10], [32,16]])
    # critic_hidden_dims  = trial.suggest_categorical("critic_hidden_dims", [[10, 10], [32,16], [32]])
    
    n_encoder_layers = trial.suggest_int("n_encoder_layers", 1, 3)
    encoder_hidden_dims = []
    for i in range(n_encoder_layers):
        # Suggest the number of nodes for each encoder layer
        dim = trial.suggest_int(f"encoder_dim_l{i}", d//2, d*3, log=True)
        encoder_hidden_dims.append(dim)
    # This is the line you need to add for the encoder
    trial.set_user_attr("encoder_hidden_dims", encoder_hidden_dims)
    

    # --- Critic Architecture Tuning ---
    # Suggest the number of hidden layers for the critic
    n_critic_layers = trial.suggest_int("n_critic_layers", 1, 5)
    critic_hidden_dims = []
    for i in range(n_critic_layers):
        # Suggest the number of nodes for each critic layer
        dim = trial.suggest_int(f"critic_dim_l{i}", d//2, d*3, log=True)
        critic_hidden_dims.append(dim)
    # This is the line you need to add for the critic
    trial.set_user_attr("critic_hidden_dims", critic_hidden_dims)


    lr_encoder = trial.suggest_float("_lr_encoder", 1e-4, 1e-2, log=True)
    lr_critic  = trial.suggest_float("_lr_critic", 1e-4, 1e-2, log=True)
    gamma = trial.suggest_float("gamma", 0.005, 10.0)
    dc_iter = trial.suggest_int("dc_iter", 5, 20)
    batch_size = trial.suggest_categorical("batch_size", [16, 32, 64])

    # Build WDGRL tune_model
    tune_model = WDGRL(
        input_dim=d,
        encoder_hidden_dims=encoder_hidden_dims,
        critic_hidden_dims=critic_hidden_dims,
        _lr_encoder=lr_encoder,
        _lr_critic=lr_critic,
        seed=42
    )
    tune_model.encoder = tune_model.encoder.float()
    tune_model.critic = tune_model.critic.float()

    # Train (shorter epochs for tuning)
    tune_model.train(
        source_dataset_small, 
        target_dataset_small,
        num_epochs=50,
        gamma=gamma,
        dc_iter=dc_iter,
        batch_size=batch_size
    )

    xs_small_hat = tune_model.extract_feature(xs_small.cuda())
    xt_small_hat = tune_model.extract_feature(xt_small.cuda())
    xs_small_hat = xs_small_hat.cpu().numpy()
    xt_small_hat = xt_small_hat.cpu().numpy()
    
    # Combine and cluster
    x_small_comb = np.vstack((xs_small_hat, xt_small_hat))
    comb_sm_cluster_labels, _ = clustering(x_small_comb)

    # Compute ARI on transported target domain
    ari = adjusted_rand_score(Yt_small, comb_sm_cluster_labels[len(xs_small_hat):])
    return ari  # Optuna will maximize this

# %%
import optuna

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=40)

print("Best params:", study.best_params)
print("Best ARI:", study.best_value)
# Out:
# [I 2025-08-09 17:04:38,742] A new study created in memory with name: no-name-447947ea-418b-4d2c-9b16-9633cf73b134
# Epoch: 100%|██████████| 50/50 [00:05<00:00,  8.78it/s]
# [I 2025-08-09 17:04:44,460] Trial 0 finished with value: -0.002526875974099521 and parameters: {'n_encoder_layers': 3, 'encoder_dim_l0': 9, 'encoder_dim_l1': 16, 'encoder_dim_l2': 8, 'n_critic_layers': 5, 'critic_dim_l0': 14, 'critic_dim_l1': 8, 'critic_dim_l2': 30, 'critic_dim_l3': 16, 'critic_dim_l4': 37, '_lr_encoder': 0.0024214298337168856, '_lr_critic': 0.0037541549435191855, 'gamma': 6.415316110755002, 'dc_iter': 20, 'batch_size': 64}. Best is trial 0 with value: -0.002526875974099521.
# Epoch: 100%|██████████| 50/50 [00:01<00:00, 28.68it/s]
# [I 2025-08-09 17:04:46,222] Trial 1 finished with value: -0.0006831036151945173 and parameters: {'n_encoder_layers': 2, 'encoder_dim_l0': 29, 'encoder_dim_l1': 16, 'n_critic_layers': 1, 'critic_dim_l0': 17, '_lr_encoder': 0.0003170309697628615, '_lr_critic': 0.0005603344779040921, 'gamma': 9.27890298342375, 'dc_iter': 12, 'batch_size': 64}. Best is trial 1 with value: -0.0006831036151945173.
# Epoch: 100%|██████████| 50/50 [00:01<00:00, 27.98it/s]
# [I 2025-08-09 17:04:48,023] Trial 2 finished with value: 0.006509092128565748 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 17, 'n_critic_layers': 2, 'critic_dim_l0': 30, 'critic_dim_l1': 33, '_lr_encoder': 0.0006452366214868231, '_lr_critic': 0.0001440639491012954, 'gamma': 9.722820439016854, 'dc_iter': 10, 'batch_size': 64}. Best is trial 2 with value: 0.006509092128565748.
# Epoch: 100%|██████████| 50/50 [00:01<00:00, 35.85it/s]
# [I 2025-08-09 17:04:49,440] Trial 3 finished with value: -0.007440907211387684 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 14, 'n_critic_layers': 4, 'critic_dim_l0': 23, 'critic_dim_l1': 10, 'critic_dim_l2': 24, 'critic_dim_l3': 33, '_lr_encoder': 0.000522783202530417, '_lr_critic': 0.00016389681864233886, 'gamma': 5.505686800270949, 'dc_iter': 6, 'batch_size': 16}. Best is trial 2 with value: 0.006509092128565748.
# Epoch: 100%|██████████| 50/50 [00:01<00:00, 41.64it/s]
# [I 2025-08-09 17:04:50,658] Trial 4 finished with value: 0.0 and parameters: {'n_encoder_layers': 2, 'encoder_dim_l0': 39, 'encoder_dim_l1': 35, 'n_critic_layers': 2, 'critic_dim_l0': 20, 'critic_dim_l1': 27, '_lr_encoder': 0.0031980806946635986, '_lr_critic': 0.00015662267724544178, 'gamma': 6.193551010455097, 'dc_iter': 7, 'batch_size': 64}. Best is trial 2 with value: 0.006509092128565748.
# Epoch: 100%|██████████| 50/50 [00:01<00:00, 29.56it/s]
# [I 2025-08-09 17:04:52,365] Trial 5 finished with value: 0.015354700148028314 and parameters: {'n_encoder_layers': 2, 'encoder_dim_l0': 42, 'encoder_dim_l1': 15, 'n_critic_layers': 4, 'critic_dim_l0': 25, 'critic_dim_l1': 18, 'critic_dim_l2': 11, 'critic_dim_l3': 36, '_lr_encoder': 0.00686288739267054, '_lr_critic': 0.00035018491956177923, 'gamma': 4.50185482421175, 'dc_iter': 7, 'batch_size': 16}. Best is trial 5 with value: 0.015354700148028314.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 20.45it/s]
# [I 2025-08-09 17:04:54,824] Trial 6 finished with value: -0.004791495245362411 and parameters: {'n_encoder_layers': 3, 'encoder_dim_l0': 10, 'encoder_dim_l1': 44, 'encoder_dim_l2': 26, 'n_critic_layers': 1, 'critic_dim_l0': 21, '_lr_encoder': 0.006498531327236411, '_lr_critic': 0.00020208392168635165, 'gamma': 0.9577479891002277, 'dc_iter': 19, 'batch_size': 16}. Best is trial 5 with value: 0.015354700148028314.
# Epoch: 100%|██████████| 50/50 [00:03<00:00, 12.63it/s]
# [I 2025-08-09 17:04:58,810] Trial 7 finished with value: -0.011953972160270707 and parameters: {'n_encoder_layers': 2, 'encoder_dim_l0': 14, 'encoder_dim_l1': 20, 'n_critic_layers': 5, 'critic_dim_l0': 10, 'critic_dim_l1': 13, 'critic_dim_l2': 20, 'critic_dim_l3': 17, 'critic_dim_l4': 9, '_lr_encoder': 0.00016590315712697624, '_lr_critic': 0.00012159285627019101, 'gamma': 7.173579122221731, 'dc_iter': 14, 'batch_size': 32}. Best is trial 5 with value: 0.015354700148028314.
# Epoch: 100%|██████████| 50/50 [00:04<00:00, 11.84it/s]
# [I 2025-08-09 17:05:03,049] Trial 8 finished with value: 0.21625101490773346 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 23, 'n_critic_layers': 4, 'critic_dim_l0': 9, 'critic_dim_l1': 12, 'critic_dim_l2': 21, 'critic_dim_l3': 13, '_lr_encoder': 0.0003789961842959467, '_lr_critic': 0.0009153322723795839, 'gamma': 2.087080255147585, 'dc_iter': 19, 'batch_size': 32}. Best is trial 8 with value: 0.21625101490773346.
# Epoch: 100%|██████████| 50/50 [00:01<00:00, 49.83it/s]
# [I 2025-08-09 17:05:04,069] Trial 9 finished with value: -0.002085676499522925 and parameters: {'n_encoder_layers': 3, 'encoder_dim_l0': 11, 'encoder_dim_l1': 15, 'encoder_dim_l2': 27, 'n_critic_layers': 1, 'critic_dim_l0': 37, '_lr_encoder': 0.007261184802793904, '_lr_critic': 0.0011039807466210884, 'gamma': 7.49954938096097, 'dc_iter': 7, 'batch_size': 32}. Best is trial 8 with value: 0.21625101490773346.
# Epoch: 100%|██████████| 50/50 [00:03<00:00, 15.92it/s]
# [I 2025-08-09 17:05:07,248] Trial 10 finished with value: 0.3830310098506779 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 26, 'n_critic_layers': 3, 'critic_dim_l0': 8, 'critic_dim_l1': 16, 'critic_dim_l2': 10, '_lr_encoder': 0.00014885712677317154, '_lr_critic': 0.0021577422151945317, 'gamma': 1.094072489124029, 'dc_iter': 16, 'batch_size': 32}. Best is trial 10 with value: 0.3830310098506779.
# Epoch: 100%|██████████| 50/50 [00:03<00:00, 15.14it/s]
# [I 2025-08-09 17:05:10,591] Trial 11 finished with value: 0.3519815405738491 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 25, 'n_critic_layers': 3, 'critic_dim_l0': 8, 'critic_dim_l1': 16, 'critic_dim_l2': 8, '_lr_encoder': 0.00010070377845952671, '_lr_critic': 0.0018947487553281133, 'gamma': 0.6332500941217438, 'dc_iter': 17, 'batch_size': 32}. Best is trial 10 with value: 0.3830310098506779.
# Epoch: 100%|██████████| 50/50 [00:03<00:00, 16.55it/s]
# [I 2025-08-09 17:05:13,659] Trial 12 finished with value: 0.2939850915571543 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 29, 'n_critic_layers': 3, 'critic_dim_l0': 8, 'critic_dim_l1': 19, 'critic_dim_l2': 8, '_lr_encoder': 0.00010282080697067761, '_lr_critic': 0.003255967479135272, 'gamma': 3.092938433530012, 'dc_iter': 16, 'batch_size': 32}. Best is trial 10 with value: 0.3830310098506779.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 16.67it/s]
# [I 2025-08-09 17:05:16,704] Trial 13 finished with value: 0.1931339060414503 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 23, 'n_critic_layers': 3, 'critic_dim_l0': 12, 'critic_dim_l1': 46, 'critic_dim_l2': 11, '_lr_encoder': 0.0001894008908018358, '_lr_critic': 0.008494043405569397, 'gamma': 0.599918322444223, 'dc_iter': 16, 'batch_size': 32}. Best is trial 10 with value: 0.3830310098506779.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 19.53it/s]
# [I 2025-08-09 17:05:19,305] Trial 14 finished with value: 0.48368308310016017 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 31, 'n_critic_layers': 2, 'critic_dim_l0': 12, 'critic_dim_l1': 15, '_lr_encoder': 0.00012696935420372464, '_lr_critic': 0.0021948804230028174, 'gamma': 3.0426816615793983, 'dc_iter': 16, 'batch_size': 32}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 23.84it/s]
# [I 2025-08-09 17:05:21,445] Trial 15 finished with value: -0.0013320395341685667 and parameters: {'n_encoder_layers': 2, 'encoder_dim_l0': 34, 'encoder_dim_l1': 8, 'n_critic_layers': 2, 'critic_dim_l0': 12, 'critic_dim_l1': 26, '_lr_encoder': 0.0012169024647281667, '_lr_critic': 0.0062967657114685795, 'gamma': 3.556015694490503, 'dc_iter': 13, 'batch_size': 32}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:01<00:00, 27.78it/s]
# [I 2025-08-09 17:05:23,290] Trial 16 finished with value: 0.24100464404278715 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 46, 'n_critic_layers': 2, 'critic_dim_l0': 11, 'critic_dim_l1': 14, '_lr_encoder': 0.0002078516934168337, '_lr_critic': 0.0018381183259211606, 'gamma': 2.324593965205837, 'dc_iter': 11, 'batch_size': 32}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 22.09it/s]
# [I 2025-08-09 17:05:25,593] Trial 17 finished with value: 0.07850131486447783 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 19, 'n_critic_layers': 2, 'critic_dim_l0': 16, 'critic_dim_l1': 24, '_lr_encoder': 0.0009496650211143202, '_lr_critic': 0.0032044206802577095, 'gamma': 1.7464207651970645, 'dc_iter': 15, 'batch_size': 32}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:03<00:00, 15.05it/s]
# [I 2025-08-09 17:05:28,957] Trial 18 finished with value: 0.35218703741444984 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 33, 'n_critic_layers': 3, 'critic_dim_l0': 47, 'critic_dim_l1': 9, 'critic_dim_l2': 43, '_lr_encoder': 0.0002870810208437698, '_lr_critic': 0.0016574622725145558, 'gamma': 4.24496591400262, 'dc_iter': 18, 'batch_size': 32}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 23.30it/s]
# [I 2025-08-09 17:05:31,145] Trial 19 finished with value: 0.19242285560925393 and parameters: {'n_encoder_layers': 2, 'encoder_dim_l0': 16, 'encoder_dim_l1': 8, 'n_critic_layers': 4, 'critic_dim_l0': 14, 'critic_dim_l1': 11, 'critic_dim_l2': 14, 'critic_dim_l3': 8, '_lr_encoder': 0.00015059829851708613, '_lr_critic': 0.004857853841646257, 'gamma': 2.6988193254899606, 'dc_iter': 9, 'batch_size': 16}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 21.99it/s]
# [I 2025-08-09 17:05:33,466] Trial 20 finished with value: 0.013694649742898527 and parameters: {'n_encoder_layers': 2, 'encoder_dim_l0': 25, 'encoder_dim_l1': 28, 'n_critic_layers': 2, 'critic_dim_l0': 10, 'critic_dim_l1': 22, '_lr_encoder': 0.001356303335271976, '_lr_critic': 0.0008345707806089998, 'gamma': 0.006783335005867919, 'dc_iter': 14, 'batch_size': 32}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:03<00:00, 14.59it/s]
# [I 2025-08-09 17:05:36,930] Trial 21 finished with value: 0.415450022041945 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 34, 'n_critic_layers': 3, 'critic_dim_l0': 45, 'critic_dim_l1': 8, 'critic_dim_l2': 42, '_lr_encoder': 0.0002645724925076603, '_lr_critic': 0.0018378095692328877, 'gamma': 4.210626040668899, 'dc_iter': 18, 'batch_size': 32}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:03<00:00, 15.92it/s]
# [I 2025-08-09 17:05:40,121] Trial 22 finished with value: 0.2174227984444558 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 36, 'n_critic_layers': 3, 'critic_dim_l0': 29, 'critic_dim_l1': 15, 'critic_dim_l2': 45, '_lr_encoder': 0.000264824267938617, '_lr_critic': 0.0023596447850511085, 'gamma': 3.6647620663864062, 'dc_iter': 17, 'batch_size': 32}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:03<00:00, 13.88it/s]
# [I 2025-08-09 17:05:43,762] Trial 23 finished with value: 0.32239076114812915 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 29, 'n_critic_layers': 3, 'critic_dim_l0': 43, 'critic_dim_l1': 9, 'critic_dim_l2': 33, '_lr_encoder': 0.00013259285413670533, '_lr_critic': 0.00128972974051974, 'gamma': 1.6269180682812936, 'dc_iter': 18, 'batch_size': 32}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:03<00:00, 13.14it/s]
# [I 2025-08-09 17:05:47,622] Trial 24 finished with value: 0.19361670555098473 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 47, 'n_critic_layers': 4, 'critic_dim_l0': 14, 'critic_dim_l1': 33, 'critic_dim_l2': 15, 'critic_dim_l3': 46, '_lr_encoder': 0.0004711244943789376, '_lr_critic': 0.0005857778097146839, 'gamma': 5.024820282763287, 'dc_iter': 15, 'batch_size': 32}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:03<00:00, 15.45it/s]
# [I 2025-08-09 17:05:50,894] Trial 25 finished with value: -0.007567865922429374 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 21, 'n_critic_layers': 2, 'critic_dim_l0': 9, 'critic_dim_l1': 16, '_lr_encoder': 0.0002146777595160989, '_lr_critic': 0.0025052115140077546, 'gamma': 3.561572425064375, 'dc_iter': 20, 'batch_size': 32}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:03<00:00, 14.60it/s]
# [I 2025-08-09 17:05:54,367] Trial 26 finished with value: 0.48368308310016017 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 31, 'n_critic_layers': 3, 'critic_dim_l0': 17, 'critic_dim_l1': 12, 'critic_dim_l2': 16, '_lr_encoder': 0.00013875408802772884, '_lr_critic': 0.0047759131537165956, 'gamma': 1.3239439365698231, 'dc_iter': 17, 'batch_size': 32}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:03<00:00, 13.83it/s]
# [I 2025-08-09 17:05:58,037] Trial 27 finished with value: 0.018890495659317694 and parameters: {'n_encoder_layers': 2, 'encoder_dim_l0': 32, 'encoder_dim_l1': 11, 'n_critic_layers': 3, 'critic_dim_l0': 17, 'critic_dim_l1': 8, 'critic_dim_l2': 15, '_lr_encoder': 0.00010601334377676444, '_lr_critic': 0.007153987637896202, 'gamma': 4.217843386535669, 'dc_iter': 18, 'batch_size': 32}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 23.00it/s]
# [I 2025-08-09 17:06:00,246] Trial 28 finished with value: 0.4487244607740242 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 39, 'n_critic_layers': 1, 'critic_dim_l0': 30, '_lr_encoder': 0.000688190961257562, '_lr_critic': 0.004745332844229212, 'gamma': 3.085619121892486, 'dc_iter': 17, 'batch_size': 16}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 18.73it/s]
# [I 2025-08-09 17:06:02,974] Trial 29 finished with value: 0.0 and parameters: {'n_encoder_layers': 3, 'encoder_dim_l0': 8, 'encoder_dim_l1': 23, 'encoder_dim_l2': 48, 'n_critic_layers': 1, 'critic_dim_l0': 33, '_lr_encoder': 0.0022198703087918, '_lr_critic': 0.004522891115575835, 'gamma': 2.701786537135499, 'dc_iter': 20, 'batch_size': 16}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:01<00:00, 31.31it/s]
# [I 2025-08-09 17:06:04,599] Trial 30 finished with value: 0.2936117468575121 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 40, 'n_critic_layers': 1, 'critic_dim_l0': 27, '_lr_encoder': 0.0007531292437826029, '_lr_critic': 0.005521287461208168, 'gamma': 1.6108854489016575, 'dc_iter': 13, 'batch_size': 16}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 19.45it/s]
# [I 2025-08-09 17:06:07,228] Trial 31 finished with value: 0.2939850915571543 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 37, 'n_critic_layers': 2, 'critic_dim_l0': 39, 'critic_dim_l1': 11, '_lr_encoder': 0.0003724695721022652, '_lr_critic': 0.004043405325052867, 'gamma': 2.939815445073299, 'dc_iter': 17, 'batch_size': 16}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 21.57it/s]
# [I 2025-08-09 17:06:09,592] Trial 32 finished with value: 0.48368308310016017 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 31, 'n_critic_layers': 1, 'critic_dim_l0': 34, '_lr_encoder': 0.00024675880056537975, '_lr_critic': 0.009263509753774598, 'gamma': 5.17413700692823, 'dc_iter': 19, 'batch_size': 64}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 20.94it/s]
# [I 2025-08-09 17:06:12,019] Trial 33 finished with value: 0.3829548950242252 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 29, 'n_critic_layers': 1, 'critic_dim_l0': 32, '_lr_encoder': 0.0004774003961091279, '_lr_critic': 0.009533939421114218, 'gamma': 5.145308274705756, 'dc_iter': 19, 'batch_size': 64}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:01<00:00, 27.21it/s]
# [I 2025-08-09 17:06:13,895] Trial 34 finished with value: 0.11375499140050858 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 42, 'n_critic_layers': 1, 'critic_dim_l0': 23, '_lr_encoder': 0.00021525454148623886, '_lr_critic': 0.00689799030589396, 'gamma': 5.961953733497158, 'dc_iter': 15, 'batch_size': 64}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 20.87it/s]
# [I 2025-08-09 17:06:16,334] Trial 35 finished with value: 0.0021685228089606758 and parameters: {'n_encoder_layers': 2, 'encoder_dim_l0': 29, 'encoder_dim_l1': 11, 'n_critic_layers': 1, 'critic_dim_l0': 18, '_lr_encoder': 0.0007261292113364277, '_lr_critic': 0.0031360777257632413, 'gamma': 6.856121936220878, 'dc_iter': 19, 'batch_size': 64}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 19.10it/s]
# [I 2025-08-09 17:06:18,986] Trial 36 finished with value: 0.2174227984444558 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 48, 'n_critic_layers': 2, 'critic_dim_l0': 15, 'critic_dim_l1': 21, '_lr_encoder': 0.00012835850802994574, '_lr_critic': 0.00984520735814131, 'gamma': 8.756928531603027, 'dc_iter': 17, 'batch_size': 64}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:01<00:00, 27.87it/s]
# [I 2025-08-09 17:06:20,817] Trial 37 finished with value: 0.415347020569299 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 31, 'n_critic_layers': 1, 'critic_dim_l0': 20, '_lr_encoder': 0.00035415739908863325, '_lr_critic': 0.003966362485180395, 'gamma': 4.686498993044108, 'dc_iter': 14, 'batch_size': 64}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:02<00:00, 20.49it/s]
# [I 2025-08-09 17:06:23,303] Trial 38 finished with value: 0.21587806660001538 and parameters: {'n_encoder_layers': 1, 'encoder_dim_l0': 38, 'n_critic_layers': 1, 'critic_dim_l0': 36, '_lr_encoder': 0.0015748260251855824, '_lr_critic': 0.006027203337781694, 'gamma': 3.5435130056224646, 'dc_iter': 20, 'batch_size': 16}. Best is trial 14 with value: 0.48368308310016017.
# Epoch: 100%|██████████| 50/50 [00:03<00:00, 13.87it/s]
# [I 2025-08-09 17:06:26,963] Trial 39 finished with value: 0.24100464404278715 and parameters: {'n_encoder_layers': 2, 'encoder_dim_l0': 27, 'encoder_dim_l1': 43, 'n_critic_layers': 5, 'critic_dim_l0': 24, 'critic_dim_l1': 13, 'critic_dim_l2': 25, 'critic_dim_l3': 8, 'critic_dim_l4': 8, '_lr_encoder': 0.0034741603199763527, '_lr_critic': 0.0027271562228954414, 'gamma': 2.1763878924026274, 'dc_iter': 12, 'batch_size': 64}. Best is trial 14 with value: 0.48368308310016017.
# Best params: {'n_encoder_layers': 1, 'encoder_dim_l0': 31, 'n_critic_layers': 2, 'critic_dim_l0': 12, 'critic_dim_l1': 15, '_lr_encoder': 0.00012696935420372464, '_lr_critic': 0.0021948804230028174, 'gamma': 3.0426816615793983, 'dc_iter': 16, 'batch_size': 32}
# Best ARI: 0.48368308310016017

# %%
print(study.best_params)
# Out:
# {'n_encoder_layers': 1, 'encoder_dim_l0': 31, 'n_critic_layers': 2, 'critic_dim_l0': 12, 'critic_dim_l1': 15, '_lr_encoder': 0.00012696935420372464, '_lr_critic': 0.0021948804230028174, 'gamma': 3.0426816615793983, 'dc_iter': 16, 'batch_size': 32}

# %%
# Assuming 'study' is your Optuna study object after optimization
best_trial = study.best_trial

print("Best Trial:")
print(f"  Value: {best_trial.value}")

print("\n  Directly Suggested Parameters:")
for key, value in best_trial.params.items():
    print(f"    {key}: {value}")

print("\n  Dynamically Generated Architecture (User Attributes):")
for key, value in best_trial.user_attrs.items():
    print(f"    {key}: {value}")
# Out:
# Best Trial:
#   Value: 0.48368308310016017
#
#   Directly Suggested Parameters:
#     n_encoder_layers: 1
#     encoder_dim_l0: 31
#     n_critic_layers: 2
#     critic_dim_l0: 12
#     critic_dim_l1: 15
#     _lr_encoder: 0.00012696935420372464
#     _lr_critic: 0.0021948804230028174
#     gamma: 3.0426816615793983
#     dc_iter: 16
#     batch_size: 32
#
#   Dynamically Generated Architecture (User Attributes):
#     encoder_hidden_dims: [31]
#     critic_hidden_dims: [12, 15]

# %%
best_trial.user_attrs["critic_hidden_dims"]
# Out:
# [12, 15]

# %%
best_params = study.best_params

final_model = WDGRL(
    input_dim=d,
    encoder_hidden_dims=best_trial.user_attrs["encoder_hidden_dims"],
    critic_hidden_dims=best_trial.user_attrs["critic_hidden_dims"],
    _lr_encoder=best_params["_lr_encoder"],
    _lr_critic=best_params["_lr_critic"],
    seed=42
)
final_model.encoder = final_model.encoder.float()
final_model.critic = final_model.critic.float()

# Train longer for final fit
final_model.train(
    source_dataset_small,
    target_dataset_small,
    num_epochs=200,  # more epochs for final training
    gamma=best_params["gamma"],
    dc_iter=best_params["dc_iter"],
    batch_size=best_params["batch_size"]
)
# Out:
# Epoch: 100%|██████████| 200/200 [00:12<00:00, 16.06it/s]
# ([], [], [])

# %%
xs_hat = final_model.extract_feature(xs.cuda())
xt_hat = final_model.extract_feature(xt.cuda())
xs_hat = xs_hat.cpu().numpy()
xt_hat = xt_hat.cpu().numpy()

# %%
gendata.visualby_tsne(xs_hat, xt_hat, Ys, Yt)
# Out:
# Running t-SNE dimensionality reduction...

# %%
x_comb = np.vstack((xs_hat, xt_hat))
comb_cluster_labels, model2 = clustering(x_comb)
ari = adjusted_rand_score(Yt, comb_cluster_labels[ns:])
print(f'Adjusted Rand Index (ARI) of target on transported domain: {ari:.4f}')
# Out:
# Adjusted Rand Index (ARI) of target on transported domain: 0.6045
